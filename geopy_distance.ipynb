# point6 =  29°16'32.00"N, 52°58'0.99"E
# point7 =  28° 4'24.00"N, 52°27'54.99"E
# point8 =  27°52'17.00"N, 52°33'21.00"E
# point9 =  28° 3'36.00"N, 52°59'56.99"E
# point10 =  28°45'9.00"N, 54° 4'34.01"E
# point11 =  28° 3'59.00"N, 54°21'12.99"E
# point12 =  27°53'34.00"N, 55°15'51.00"E

# station1 =  31°10'12.84"N, 52°34'50.50"E
# station2 =  31° 0'24.47"N, 52°45'0.63"E
# station3 =  30°35'6.03"N, 53°11'41.32"E
# station4 =  30°21'48.39"N, 53°20'59.60"E
# station5 =  30° 6'19.31"N, 53° 5'39.18"E
# station6 =  29°53'47.61"N, 52°48'5.92"E
# station7 =  29°45'50.94"N, 52°25'52.89"E

# shiraz_WWT_No_1 = 29°32'35.20"N, 52°38'17.05"E
# shiraz_WWT_No_2=  29°28'28.92"N, 52°34'5.48"E
# shiraz_industrial_WWT = 29°28'32.68"N, 52°33'52.02"E
# kazerun_WWT = 29°37'10.59"N, 51°36'31.87"E
# eqlid_WWT = 30°59'27.10"N, 52°47'0.84"E
# jahrom_WWT_No_1 = 28°35'4.27"N, 53°33'34.11"E
# jahrom_WWT_No_2 = 28°29'55.73"N, 53°26'26.26"E

# shiraz_oil_refinery = 29°44'12.45"N, 52°39'13.24"E
# farashband_gas_refinery = 28°41'6.82"N, 52° 4'57.74"E

# %%
import re
from geopy.distance import geodesic
import csv

def dms_to_decimal(dms_str):
    parts = re.split('[°\'"]+', dms_str)
    degrees = float(parts[0])
    minutes = float(parts[1])
    seconds = float(parts[2])
    direction = parts[3]
    
    decimal = degrees + minutes / 60 + seconds / 3600
    
    if direction in ['S', 'W']:
        decimal = -decimal
    
    return decimal

# cities = {
#     'abadeh': ("31° 9'45.00\"N", "52°38'54.00\"E"),
#     'ardakan': ("30°15'27.00\"N", "51°59'9.99\"E"),
#     'arsenjan': ("29°54'50.00\"N", "53°18'0.99\"E"),
#     'bakhtegan': ("29°48'33.00\"N", "53°43'36.00\"E"),
#     'bavanat': ("30°29'23.00\"N", "53°35'38.00\"E"),
#     'beyza': ("29°58'20.00\"N", "52°24'3.00\"E"),
#     'darab': ("28°45'14.00\"N", "54°32'44.99\"E"),     
#     'eqlid': ("30°53'36.20\"N", "52°41'20.99\"E"), 
#     'estahban': ("29° 7'36.00\"N", "54° 2'20.98\"E"),
#     'evaz': ("27°45'35.00\"N", "54° 0'23.00\"E"),
#     'farashband': ("28°51'35.00\"N", "52° 5'40.00\"E"),
#     'fasa': ("28°56'54.00\"N", "53°38'15.00\"E"),
#     'firuzabad': ("28°50'48.00\"N", "52°34'11.01\"E"),
#     'gerash': ("27°39'51.00\"N", "54° 8'45.00\"E"),
#     'ghir': ("28°28'57.00\"N", "53° 2'12.00\"E"),
#     'jahrom': ("28°30'26.00\"N", "53°34'9.00\"E"),
#     'kavar': ("29°12'16.00\"N", "52°41'31.00\"E"),
#     'kazerun': ("29°37'12.00\"N", "51°38'53.00\"E"),
#     'kerehee': ("30° 1'52.00\"N", "53°43'1.00\"E"),
#     'jahrom_WWT_No_2': ("28°29'55.73\"N", "53°26'26.26\"E"),
#     'kazerun_WWT': ("29°37'10.59\"N", "51°36'31.87\"E"),
#     'shiraz_industrial_WWT': ("29°28'32.68\"N", "52°33'52.02\"E"),  
#     'shiraz_WWT_No_1': ("29°32'35.20\"N", "52°38'17.05\"E"),
#     'shiraz_WWT_No_2': ("29°28'28.92\"N", "52°34'5.48\"E"),   
#     }

# refineries = {
#     'shiraz_oil_refinery': ("29°44'12.45\"N", "52°39'13.24\"E"),
#     'farashband_gas_refinery': ("28°41'6.82\"N", "52° 4'57.74\"E")
#     }

#decimal_cities = {city: (dms_to_decimal(lat), dms_to_decimal(lon)) for city, (lat, lon) in cities.items()}

decimal_power_plants = {power_plant: (dms_to_decimal(lat), dms_to_decimal(lon)) for power_plant, (lat, lon) in power_plants.items()}

# decimal_candidates = {point: (dms_to_decimal(lat), dms_to_decimal(lon)) for point, (lat, lon) in candidate_points.items()}

decimal_stations = {station: (dms_to_decimal(lat), dms_to_decimal(lon)) for station, (lat, lon) in rail_stations.items()}

# decimal_WWT = {WWT: (dms_to_decimal(lat), dms_to_decimal(lon)) for WWT, (lat, lon) in WWT_plants.items()}

#decimal_refineries = {refinery: (dms_to_decimal(lat), dms_to_decimal(lon)) for refinery, (lat, lon) in refineries.items()}


# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_s_p = []

# for refinery, coords1 in decimal_refineries.items():
#     distances = []
#     for plant, coords2 in decimal_power_plants.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_s_p.append(distances)

# with open('desktop/distance_s_p.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_power_plants.keys())) 
#     for point, distances in zip(decimal_refineries.keys(), distance_s_p):
#         writer.writerow([point] + distances) 

# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_s_r = []

# for refinery, coords1 in decimal_refineries.items():
#     distances = []
#     for station, coords2 in decimal_stations.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_s_r.append(distances)

# with open('desktop/distance_s_r.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_stations.keys())) 
#     for point, distances in zip(decimal_refineries.keys(), distance_s_r):
#         writer.writerow([point] + distances) 
        
# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_i_b = []

# for city, coords1 in decimal_cities.items():
#     distances = []
#     for point, coords2 in decimal_candidates.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_i_b.append(distances)

# with open('desktop/distance_i_b.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_candidates.keys())) 
#     for point, distances in zip(decimal_cities.keys(), distance_i_b):
#         writer.writerow([point] + distances) 

# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_i_r = []

# for city, coords1 in decimal_cities.items():
#     distances = []
#     for station, coords2 in decimal_stations.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_i_r.append(distances)

# with open('desktop/distance_i_r.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_stations.keys())) 
#     for point, distances in zip(decimal_cities.keys(), distance_i_r):
#         writer.writerow([point] + distances) 

# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_r_b = []

# for station, coords1 in decimal_stations.items():
#     distances = []
#     for point, coords2 in decimal_candidates.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_r_b.append(distances)

# with open('desktop/distance_r_b.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_candidates.keys())) 
#     for point, distances in zip(decimal_stations.keys(), distance_r_b):
#         writer.writerow([point] + distances) 
        
# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_r_rp = []

# for station1, coords1 in decimal_stations.items():
#     distances = []
#     for station2, coords2 in decimal_stations.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_r_rp.append(distances)

# with open('desktop/distance_r_rp.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_stations.keys())) 
#     for point, distances in zip(decimal_stations.keys(), distance_r_rp):
#         writer.writerow([point] + distances) 
        
# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_b_r = []

# for point, coords1 in decimal_candidates.items():
#     distances = []
#     for station, coords2 in decimal_stations.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_b_r.append(distances)

# with open('desktop/distance_b_r.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_stations.keys())) 
#     for point, distances in zip(decimal_candidates.keys(), distance_b_r):
#         writer.writerow([point] + distances)
    
# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_r_m = []

# for station, coords1 in decimal_stations.items():
#     distances = []
#     for city, coords2 in decimal_cities.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_r_m.append(distances)

# with open('desktop/distance_r_m.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_cities.keys())) 
#     for point, distances in zip(decimal_stations.keys(), distance_r_m):
#         writer.writerow([point] + distances)
        
# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_b_p = []

# for point, coords1 in decimal_candidates.items():
#     distances = []
#     for plant, coords2 in decimal_power_plants.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_b_p.append(distances)

# with open('desktop/distance_b_p.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_power_plants.keys())) 
#     for point, distances in zip(decimal_candidates.keys(), distance_b_p):
#         writer.writerow([point] + distances)  

# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

distance_r_p = []

for station, coords1 in decimal_stations.items():
    distances = []
    for plant, coords2 in decimal_power_plants.items(): 
        distances.append(geodesic(coords1, coords2).kilometers)
    distance_r_p.append(distances)

with open('desktop/distance_r_p.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow([''] + list(decimal_power_plants.keys())) 
    for point, distances in zip(decimal_stations.keys(), distance_r_p):
        writer.writerow([point] + distances)  
        
# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# distance_d_m = []

# for point, coords1 in decimal_candidates.items():
#     distances = []
#     for city, coords2 in decimal_cities.items(): 
#         distances.append(geodesic(coords1, coords2).kilometers)
#     distance_d_m.append(distances)

# with open('desktop/distance_d_m.csv', 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerow([''] + list(decimal_cities.keys())) 
#     for point, distances in zip(decimal_candidates.keys(), distance_d_m):
#         writer.writerow([point] + distances)

# """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
